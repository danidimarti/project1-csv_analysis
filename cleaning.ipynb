# %% [markdown]
# ### Libraries

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import DateTime as dtm

# %% [markdown]
# ### Import Data

# %%
df = pd.read_csv("data/attacks.csv", encoding='cp1252')

# %%
#checks if there's still rows with empty cells 
df.isna()
# Out:
#        Case Number   Date   Year   Type  Country   Area  Location  Activity  \
# 0            False  False  False  False    False  False     False     False
# 1            False  False  False  False    False  False     False     False
# 2            False  False  False  False    False  False     False     False
# 3            False  False  False  False    False  False     False     False
# 4            False  False  False  False    False  False     False     False
# ...            ...    ...    ...    ...      ...    ...       ...       ...
# 25718         True   True   True   True     True   True      True      True
# 25719         True   True   True   True     True   True      True      True
# 25720         True   True   True   True     True   True      True      True
# 25721         True   True   True   True     True   True      True      True
# 25722        False   True   True   True     True   True      True      True
#
#         Name   Sex   ...  Species   Investigator or Source    pdf  \
# 0      False  False  ...     False                   False  False
# 1      False  False  ...      True                   False  False
# 2      False  False  ...      True                   False  False
# 3      False  False  ...     False                   False  False
# 4      False  False  ...     False                   False  False
# ...      ...    ...  ...       ...                     ...    ...
# 25718   True   True  ...      True                    True   True
# 25719   True   True  ...      True                    True   True
# 25720   True   True  ...      True                    True   True
# 25721   True   True  ...      True                    True   True
# 25722   True   True  ...      True                    True   True
#
#        href formula   href  Case Number.1  Case Number.2  original order  \
# 0             False  False          False          False           False
# 1             False  False          False          False           False
# 2             False  False          False          False           False
# 3             False  False          False          False           False
# 4             False  False          False          False           False
# ...             ...    ...            ...            ...             ...
# 25718          True   True           True           True            True
# 25719          True   True           True           True            True
# 25720          True   True           True           True            True
# 25721          True   True           True           True            True
# 25722          True   True           True           True            True
#
#        Unnamed: 22  Unnamed: 23
# 0             True         True
# 1             True         True
# 2             True         True
# 3             True         True
# 4             True         True
# ...            ...          ...
# 25718         True         True
# 25719         True         True
# 25720         True         True
# 25721         True         True
# 25722         True         True
#
# [25723 rows x 24 columns]

# %%
#drop rows of data that are empty
df.dropna(axis=0, how='all')
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 8698            0          NaN     NaN         NaN        NaN
# 8699            0          NaN     NaN         NaN        NaN
# 8700            0          NaN     NaN         NaN        NaN
# 8701            0          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 8698               NaN                             NaN          NaN
# 8699               NaN                             NaN          NaN
# 8700               NaN                             NaN          NaN
# 8701               NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
#
#                   Name Sex   ...         Species   \
# 0          Julie Wolfe    F  ...      White shark
# 1      Adyson McNeely     F  ...              NaN
# 2          John Denges    M  ...              NaN
# 3                 male    M  ...        2 m shark
# 4       Gustavo Ramos     M  ...  Tiger shark, 3m
# ...                ...  ...  ...              ...
# 8698               NaN  NaN  ...              NaN
# 8699               NaN  NaN  ...              NaN
# 8700               NaN  NaN  ...              NaN
# 8701               NaN  NaN  ...              NaN
# 25722              NaN  NaN  ...              NaN
#
#                Investigator or Source                       pdf  \
# 0                    R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1      K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2      K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3                      B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4                           A .Kipper      2018.06.04-Ramos.pdf
# ...                               ...                       ...
# 8698                              NaN                       NaN
# 8699                              NaN                       NaN
# 8700                              NaN                       NaN
# 8701                              NaN                       NaN
# 25722                             NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 8698                                                 NaN
# 8699                                                 NaN
# 8700                                                 NaN
# 8701                                                 NaN
# 25722                                                NaN
#
#                                                     href Case Number.1  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                  ...           ...
# 8698                                                 NaN           NaN
# 8699                                                 NaN           NaN
# 8700                                                 NaN           NaN
# 8701                                                 NaN           NaN
# 25722                                                NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0        2018.06.25         6303.0         NaN         NaN
# 1        2018.06.18         6302.0         NaN         NaN
# 2        2018.06.09         6301.0         NaN         NaN
# 3        2018.06.08         6300.0         NaN         NaN
# 4        2018.06.04         6299.0         NaN         NaN
# ...             ...            ...         ...         ...
# 8698            NaN            NaN         NaN         NaN
# 8699            NaN            NaN         NaN         NaN
# 8700            NaN            NaN         NaN         NaN
# 8701            NaN            NaN         NaN         NaN
# 25722           NaN            NaN         NaN         NaN
#
# [8703 rows x 24 columns]

# %%
df.columns=df.columns.str.capitalize().str.replace(' ','-')
df.columns= df.columns.str.rstrip(' ')

# %%
df.sample()
# Out:
#        Case-number                   Date    Year        Type    Country Area  \
# 5800  1882.02.07.R  Reported  07-Feb-1882  1882.0  Unprovoked  AUSTRALIA  NaN
#
#      Location      Activity            Name Sex-  ... Species-  \
# 5800      NaN  Pearl diving  a native diver    M  ...      NaN
#
#           Investigator-or-source                          Pdf  \
# 5800  West Australian, 3/28/1882  1882.02.07.R-PearlDiver.pdf
#
#                                            Href-formula  \
# 5800  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    Href Case-number.1  \
# 5800  http://sharkattackfile.net/spreadsheets/pdf_di...  1882.02.07.R
#
#      Case-number.2 Original-order Unnamed:-22 Unnamed:-23
# 5800  1882.02.07.R          503.0         NaN         NaN
#
# [1 rows x 24 columns]

# %%
lst = list(df.columns)
print(lst)
# Out:
# ['Case-number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location', 'Activity', 'Name', 'Sex-', 'Age', 'Injury', 'Fatal-(y/n)', 'Time', 'Species-', 'Investigator-or-source', 'Pdf', 'Href-formula', 'Href', 'Case-number.1', 'Case-number.2', 'Original-order', 'Unnamed:-22', 'Unnamed:-23']

# %% [markdown]
# ### Consistent Naming Convention:
#
# #### Column Names
# 1. Capitalized
# 2. Words Separated by '-'

# %%
df['Species-'] = df['Species-'].str.rstrip('-')

# %%
#fill NaN values from species column with 'Unknown'
#df['Species-'].fillna('Unknown', inplace=True)

# %%
#fill NaN values from activity column with 'Unknown'
#df['Activity'].fillna('Unknown', inplace=True)

# %%
# Fix capitalization of fatal(y/n) 
df['Fatal-(y/n)'] = df['Fatal-(y/n)'].str.upper()

# %%
df['Fatal-(y/n)'] = df['Fatal-(y/n)'].str.strip(" ")

# %%
# if column not Y or N, assign as UNKNOWN
df['Fatal-(y/n)'] = np.where((df["Fatal-(y/n)"] == "2017") | (df["Fatal-(y/n)"] == "M"), "UNKNOWN", df["Fatal-(y/n)"])
df["Fatal-(y/n)"].value_counts()
# Out:
# N          4301
# Y          1389
# UNKNOWN      73
# Name: Fatal-(y/n), dtype: int64

# %%
# Remove words ending with dash
df.rename({'Species-': "Species", "Sex-": "Sex", 'Fatal-(y/n)': 'Fatal'}, axis=1, inplace=True)

# %%
#consistent capitalization
df['Activity'] = df['Activity'].str.capitalize()
df['Type'] = df['Type'].str.capitalize()
df['Country'] = df['Country'].str.capitalize()
df['Species'] = df['Species'].str.capitalize()

# %%
#df2 = df['activity'].value_counts().apply(lambda x: "Other" if x < 10 else x)
#df2

# %%
#df['activity'].apply(lambda x: "Other" if x < 10 else x)
#d = df.activity.value_counts().to_dict()
#df['activity'] = df['activity'].map(lambda x : x  if d[x] > 10 else 'Other')

# %%
#df.activity.value_counts()

# %%
df.Type.value_counts()
# Out:
# Unprovoked      4595
# Provoked         574
# Invalid          547
# Sea disaster     239
# Boating          203
# Boat             137
# Questionable       2
# Boatomg            1
# Name: Type, dtype: int64

# %%
#fill NaN values from columns
#df['species'].fillna('Unknown', inplace=True)
#df['country'].fillna('Unknown', inplace=True)
#df['type'].fillna('Unknown', inplace=True)

# %% [markdown]
# ### Fix _Year_ Column
#
# 1. Drop NaN values
# 2. Drop invalid based year format (e.g. year != 52)
# 2. Remove floats (.0)

# %%
df.dropna(subset=["Year"], inplace=True)

# %%
df['Year'] = df['Year'].astype(str)

# %%
df['Year'].unique
# Out:
# <bound method Series.unique of 0       2018.0
# 1       2018.0
# 2       2018.0
# 3       2018.0
# 4       2018.0
#          ...
# 6297       0.0
# 6298       0.0
# 6299       0.0
# 6300       0.0
# 6301       0.0
# Name: Year, Length: 6300, dtype: object>

# %%
df['Year'] = df['Year'].map(lambda x: x.rstrip('.0'))

# %%
df["Year"].unique()
# Out:
# array(['2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011',
#        '201', '2009', '2008', '2007', '2006', '2005', '2004', '2003',
#        '2002', '2001', '2', '1999', '1998', '1997', '1996', '1995',
#        '1984', '1994', '1993', '1992', '1991', '199', '1989', '1969',
#        '1988', '1987', '1986', '1985', '1983', '1982', '1981', '198',
#        '1979', '1978', '1977', '1976', '1975', '1974', '1973', '1972',
#        '1971', '197', '1968', '1967', '1966', '1965', '1964', '1963',
#        '1962', '1961', '196', '1959', '1958', '1957', '1956', '1955',
#        '1954', '1953', '1952', '1951', '195', '1949', '1948', '1848',
#        '1947', '1946', '1945', '1944', '1943', '1942', '1941', '194',
#        '1939', '1938', '1937', '1936', '1935', '1934', '1933', '1932',
#        '1931', '193', '1929', '1928', '1927', '1926', '1925', '1924',
#        '1923', '1922', '1921', '192', '1919', '1918', '1917', '1916',
#        '1915', '1914', '1913', '1912', '1911', '191', '1909', '1908',
#        '1907', '1906', '1905', '1904', '1903', '1902', '1901', '19',
#        '1899', '1898', '1897', '1896', '1895', '1894', '1893', '1892',
#        '1891', '189', '1889', '1888', '1887', '1886', '1885', '1884',
#        '1883', '1882', '1881', '188', '1879', '1878', '1877', '1876',
#        '1875', '1874', '1873', '1872', '1871', '187', '1869', '1868',
#        '1867', '1866', '1865', '1864', '1863', '1862', '1861', '186',
#        '1859', '1858', '1857', '1856', '1855', '1853', '1852', '1851',
#        '185', '1849', '1847', '1846', '1845', '1844', '1842', '1841',
#        '184', '1839', '1837', '1836', '1835', '1834', '1832', '1831',
#        '183', '1829', '1828', '1827', '1826', '1825', '1823', '1822',
#        '1819', '1818', '1817', '1816', '1815', '1812', '1811', '181',
#        '1808', '1807', '1805', '1804', '1803', '1802', '1801', '18',
#        '1797', '1792', '1791', '1788', '1787', '1786', '1785', '1784',
#        '1783', '178', '1779', '1776', '1771', '1767', '1764', '1758',
#        '1753', '1751', '1749', '1755', '1748', '1742', '1738', '1733',
#        '1723', '1721', '1703', '17', '1642', '1638', '1637', '1617',
#        '1595', '158', '1555', '1554', '1543', '5', '77', ''], dtype=object)

# %%
df["Year"] = df['Year'].apply(lambda x: "" if len(x) != 4 else x)

# %%
df["Year"].unique()
# Out:
# array(['2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011', '',
#        '2009', '2008', '2007', '2006', '2005', '2004', '2003', '2002',
#        '2001', '1999', '1998', '1997', '1996', '1995', '1984', '1994',
#        '1993', '1992', '1991', '1989', '1969', '1988', '1987', '1986',
#        '1985', '1983', '1982', '1981', '1979', '1978', '1977', '1976',
#        '1975', '1974', '1973', '1972', '1971', '1968', '1967', '1966',
#        '1965', '1964', '1963', '1962', '1961', '1959', '1958', '1957',
#        '1956', '1955', '1954', '1953', '1952', '1951', '1949', '1948',
#        '1848', '1947', '1946', '1945', '1944', '1943', '1942', '1941',
#        '1939', '1938', '1937', '1936', '1935', '1934', '1933', '1932',
#        '1931', '1929', '1928', '1927', '1926', '1925', '1924', '1923',
#        '1922', '1921', '1919', '1918', '1917', '1916', '1915', '1914',
#        '1913', '1912', '1911', '1909', '1908', '1907', '1906', '1905',
#        '1904', '1903', '1902', '1901', '1899', '1898', '1897', '1896',
#        '1895', '1894', '1893', '1892', '1891', '1889', '1888', '1887',
#        '1886', '1885', '1884', '1883', '1882', '1881', '1879', '1878',
#        '1877', '1876', '1875', '1874', '1873', '1872', '1871', '1869',
#        '1868', '1867', '1866', '1865', '1864', '1863', '1862', '1861',
#        '1859', '1858', '1857', '1856', '1855', '1853', '1852', '1851',
#        '1849', '1847', '1846', '1845', '1844', '1842', '1841', '1839',
#        '1837', '1836', '1835', '1834', '1832', '1831', '1829', '1828',
#        '1827', '1826', '1825', '1823', '1822', '1819', '1818', '1817',
#        '1816', '1815', '1812', '1811', '1808', '1807', '1805', '1804',
#        '1803', '1802', '1801', '1797', '1792', '1791', '1788', '1787',
#        '1786', '1785', '1784', '1783', '1779', '1776', '1771', '1767',
#        '1764', '1758', '1753', '1751', '1749', '1755', '1748', '1742',
#        '1738', '1733', '1723', '1721', '1703', '1642', '1638', '1637',
#        '1617', '1595', '1555', '1554', '1543'], dtype=object)

# %%
#df["Year"] = df['Year'].apply(lambda x: "" if len(x) != 4 else x)

# %%
#df['Year'] = pd.to_numeric(df['Year'], errors='coerce')
df.dropna(subset=['Year'], inplace=True)
#df['Year'] = pd.to_datetime(df['Year'], format='%Y', exact=True, errors='ignore')

# %%
df['Year'] = pd.to_datetime(df['Year'], format='%Y', errors='coerce')

# %%
df.sample(10)
# Out:
#        Case-number         Date       Year        Type       Country  \
# 3828    1962.04.05  05-Apr-1962 1962-01-01    Provoked  South africa
# 349     2015.10.08  08-Oct-2015 2015-01-01  Unprovoked    Mozambique
# 3472    1968.05.18  18-May-1968 1968-01-01     Invalid      Tanzania
# 356     2015.09.24  24-Sep-2015 2015-01-01     Boating           Usa
# 5032    1930.12.02  02-Dec-1930        NaT     Boating     Australia
# 1638    2004.09.20  20-Sep-2004 2004-01-01  Unprovoked           Usa
# 2823    1986.03.15  15-Mar-1986 1986-01-01  Unprovoked  South africa
# 5276    1919.00.00         1919 1919-01-01  Unprovoked           Usa
# 2513  1993.00.00.d    Fall 1993 1993-01-01  Unprovoked        Angola
# 5734    1888.02.00     Feb-1888 1888-01-01  Unprovoked  South africa
#
#                        Area                              Location  \
# 3828  Eastern Cape Province                           East London
# 349      Inhambane Province                 Maxixe, Inhambane Bay
# 3472           Mafia Island                                   NaN
# 356              California  Horseshoe Rock, Santa Barbara County
# 5032               Victoria                               Rosebud
# 1638                 Oregon                           Gold  Beach
# 2823          KwaZulu-Natal                   North Beach, Durban
# 5276                Florida          Near Panama City, Bay County
# 2513            West Africa                                   NaN
# 5734  Eastern Cape Province                  Mzimvubu River mouth
#
#                           Activity  \
# 3828                       Fishing
# 349                        Fishing
# 3472  Schooner sank during a storm
# 356                  Kayak fishing
# 5032                       Fishing
# 1638                       Surfing
# 2823                Treading water
# 5276                      Swimming
# 2513                       Surfing
# 5734      Crossing the river mouth
#
#                                                Name  Sex  ...  \
# 3828  4.8 m skiboat, occupants: C. Cockroft & 3 men  NaN  ...
# 349                                  Alberto Rafael    M  ...
# 3472                                            NaN  NaN  ...
# 356                                   Darren Kenney    M  ...
# 5032                                     12' dinghy  NaN  ...
# 1638                                      Seth Mead    M  ...
# 2823                                   Anton Bouwer    M  ...
# 5276                     adult female (Mrs. Avery?)    F  ...
# 2513                                     John Doyle    M  ...
# 5734                                           male    M  ...
#
#                                                 Species  \
# 3828                                   4.9 m [16']shark
# 349                                                 NaN
# 3472                    Shark involvement not confirmed
# 356                                    White shark, 19'
# 5032  7 shark's teeth found embedded in the woodwork...
# 1638                                        White shark
# 2823                                         >1 m shark
# 5276                                                NaN
# 2513                              3 m [10'] white shark
# 5734                                                NaN
#
#                                  Investigator-or-source  \
# 3828                                         T. Wallett
# 349                                  Club of Mozambique
# 3472                                         R. Wharton
# 356                                          R. Collier
# 5032                                G.P. Whitley, p.262
# 1638        S. Mead, R. Collier, J. Eager, B. Middleton
# 2823         A. Bouwer, M. Levine, GSAF;  E. Kerns, NSB
# 5276  R. F. Hutton; T. Helm, p.219; V.M. Coppleson (...
# 2513                                    Internet report
# 5734  Cape Mercantile Advertiser, 2/15/1888, M. Levi...
#
#                              Pdf  \
# 3828     1962.04.05-Cockroft.pdf
# 349        2015.10.08-Rafael.pdf
# 3472  1968.05.18-MafiaIsland.pdf
# 356        2015.09.24-Kenney.pdf
# 5032       1930.12.02-dinghy.pdf
# 1638         2004.09.20-Mead.pdf
# 2823       1986.03.15-Bouwer.pdf
# 5276     1919.00.00-MrsAvery.pdf
# 2513      1993.00.00.d-Doyle.pdf
# 5734     1888.02.00-Mzimvubu.pdf
#
#                                            Href-formula  \
# 3828  http://sharkattackfile.net/spreadsheets/pdf_di...
# 349   http://sharkattackfile.net/spreadsheets/pdf_di...
# 3472  http://sharkattackfile.net/spreadsheets/pdf_di...
# 356   http://sharkattackfile.net/spreadsheets/pdf_di...
# 5032  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1638  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2823  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5276  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2513  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5734  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    Href Case-number.1  \
# 3828  http://sharkattackfile.net/spreadsheets/pdf_di...    1962.04.05
# 349   http://sharkattackfile.net/spreadsheets/pdf_di...    2015.10.08
# 3472  http://sharkattackfile.net/spreadsheets/pdf_di...    1968.05.18
# 356   http://sharkattackfile.net/spreadsheets/pdf_di...    2015.09.24
# 5032  http://sharkattackfile.net/spreadsheets/pdf_di...    1930.12.02
# 1638  http://sharkattackfile.net/spreadsheets/pdf_di...    2004.09.20
# 2823  http://sharkattackfile.net/spreadsheets/pdf_di...    1986.03.15
# 5276  http://sharkattackfile.net/spreadsheets/pdf_di...    1919.00.00
# 2513  http://sharkattackfile.net/spreadsheets/pdf_di...  1993.00.00.d
# 5734  http://sharkattackfile.net/spreadsheets/pdf_di...    1888.02.00
#
#      Case-number.2 Original-order Unnamed:-22 Unnamed:-23
# 3828    1962.04.05         2475.0         NaN         NaN
# 349     2015.10.08         5954.0         NaN         NaN
# 3472    1968.05.18         2831.0         NaN         NaN
# 356     2015.09.24         5947.0         NaN         NaN
# 5032    1930.12.02         1271.0         NaN         NaN
# 1638    2004.09.20         4665.0         NaN         NaN
# 2823    1986.03.15         3480.0         NaN         NaN
# 5276    1919.00.00         1027.0         NaN         NaN
# 2513  1993.00.00.d         3790.0         NaN         NaN
# 5734    1888.02.00          569.0         NaN         NaN
#
# [10 rows x 24 columns]

# %%
df["Year"].dtypes
# Out:
# dtype('<M8[ns]')

# %%
df['Year'].unique()
# Out:
# array(['2018-01-01T00:00:00.000000000', '2017-01-01T00:00:00.000000000',
#        '2016-01-01T00:00:00.000000000', '2015-01-01T00:00:00.000000000',
#        '2014-01-01T00:00:00.000000000', '2013-01-01T00:00:00.000000000',
#        '2012-01-01T00:00:00.000000000', '2011-01-01T00:00:00.000000000',
#                                  'NaT', '2009-01-01T00:00:00.000000000',
#        '2008-01-01T00:00:00.000000000', '2007-01-01T00:00:00.000000000',
#        '2006-01-01T00:00:00.000000000', '2005-01-01T00:00:00.000000000',
#        '2004-01-01T00:00:00.000000000', '2003-01-01T00:00:00.000000000',
#        '2002-01-01T00:00:00.000000000', '2001-01-01T00:00:00.000000000',
#        '1999-01-01T00:00:00.000000000', '1998-01-01T00:00:00.000000000',
#        '1997-01-01T00:00:00.000000000', '1996-01-01T00:00:00.000000000',
#        '1995-01-01T00:00:00.000000000', '1984-01-01T00:00:00.000000000',
#        '1994-01-01T00:00:00.000000000', '1993-01-01T00:00:00.000000000',
#        '1992-01-01T00:00:00.000000000', '1991-01-01T00:00:00.000000000',
#        '1989-01-01T00:00:00.000000000', '1969-01-01T00:00:00.000000000',
#        '1988-01-01T00:00:00.000000000', '1987-01-01T00:00:00.000000000',
#        '1986-01-01T00:00:00.000000000', '1985-01-01T00:00:00.000000000',
#        '1983-01-01T00:00:00.000000000', '1982-01-01T00:00:00.000000000',
#        '1981-01-01T00:00:00.000000000', '1979-01-01T00:00:00.000000000',
#        '1978-01-01T00:00:00.000000000', '1977-01-01T00:00:00.000000000',
#        '1976-01-01T00:00:00.000000000', '1975-01-01T00:00:00.000000000',
#        '1974-01-01T00:00:00.000000000', '1973-01-01T00:00:00.000000000',
#        '1972-01-01T00:00:00.000000000', '1971-01-01T00:00:00.000000000',
#        '1968-01-01T00:00:00.000000000', '1967-01-01T00:00:00.000000000',
#        '1966-01-01T00:00:00.000000000', '1965-01-01T00:00:00.000000000',
#        '1964-01-01T00:00:00.000000000', '1963-01-01T00:00:00.000000000',
#        '1962-01-01T00:00:00.000000000', '1961-01-01T00:00:00.000000000',
#        '1959-01-01T00:00:00.000000000', '1958-01-01T00:00:00.000000000',
01T00:00:00.000000000'],
#       dtype='datetime64[ns]')

# %%
#df['Year'] = pd.DatetimeIndex(df['Year']).year

# %%
df.Year = pd.to_datetime(df.Year).dt.year

# %%
df["Year"].dtypes
# Out:
# dtype('float64')

# %%
df['Year'].unique()
# Out:
# array([2018., 2017., 2016., 2015., 2014., 2013., 2012., 2011.,   nan,
#        2009., 2008., 2007., 2006., 2005., 2004., 2003., 2002., 2001.,
#        1999., 1998., 1997., 1996., 1995., 1984., 1994., 1993., 1992.,
#        1991., 1989., 1969., 1988., 1987., 1986., 1985., 1983., 1982.,
#        1981., 1979., 1978., 1977., 1976., 1975., 1974., 1973., 1972.,
#        1971., 1968., 1967., 1966., 1965., 1964., 1963., 1962., 1961.,
#        1959., 1958., 1957., 1956., 1955., 1954., 1953., 1952., 1951.,
#        1949., 1948., 1848., 1947., 1946., 1945., 1944., 1943., 1942.,
#        1941., 1939., 1938., 1937., 1936., 1935., 1934., 1933., 1932.,
#        1931., 1929., 1928., 1927., 1926., 1925., 1924., 1923., 1922.,
#        1921., 1919., 1918., 1917., 1916., 1915., 1914., 1913., 1912.,
#        1911., 1909., 1908., 1907., 1906., 1905., 1904., 1903., 1902.,
#        1901., 1899., 1898., 1897., 1896., 1895., 1894., 1893., 1892.,
#        1891., 1889., 1888., 1887., 1886., 1885., 1884., 1883., 1882.,
#        1881., 1879., 1878., 1877., 1876., 1875., 1874., 1873., 1872.,
#        1871., 1869., 1868., 1867., 1866., 1865., 1864., 1863., 1862.,
#        1861., 1859., 1858., 1857., 1856., 1855., 1853., 1852., 1851.,
#        1849., 1847., 1846., 1845., 1844., 1842., 1841., 1839., 1837.,
#        1836., 1835., 1834., 1832., 1831., 1829., 1828., 1827., 1826.,
#        1825., 1823., 1822., 1819., 1818., 1817., 1816., 1815., 1812.,
#        1811., 1808., 1807., 1805., 1804., 1803., 1802., 1801., 1797.,
#        1792., 1791., 1788., 1787., 1786., 1785., 1784., 1783., 1779.,
#        1776., 1771., 1767., 1764., 1758., 1753., 1751., 1749., 1755.,
#        1748., 1742., 1738., 1733., 1723., 1721., 1703.])

# %% [markdown]
# ### Removed Duplicates, keeping first
# 1. Drop duplicated rows considering all columns

# %%
df = df.drop_duplicates(keep='first')

# %%
df[['Year','Country', 'Type','Fatal']].head(100)
# Out:
#       Year      Country        Type Fatal
# 0   2018.0          Usa     Boating     N
# 1   2018.0          Usa  Unprovoked     N
# 2   2018.0          Usa     Invalid     N
# 3   2018.0    Australia  Unprovoked     N
# 4   2018.0       Mexico    Provoked     N
# ..     ...          ...         ...   ...
# 95  2017.0          Usa  Unprovoked     N
# 96  2017.0    Australia  Unprovoked     N
# 97  2017.0          Usa  Unprovoked     N
# 98  2017.0        Spain     Invalid   NaN
# 99  2017.0  New zealand  Unprovoked     N
#
# [100 rows x 4 columns]

# %%
df.to_csv('data/clean_sharks_export.csv')
