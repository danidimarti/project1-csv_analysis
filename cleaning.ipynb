# %% [markdown]
# ### Libraries

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import DataTime as dtm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[531], line 5
#       3 import pandas as pd
#       4 import numpy as np
# ----> 5 import DataTime as dtm
#
# ModuleNotFoundError: No module named 'DataTime'

# %%
df = pd.read_csv("data/attacks.csv", encoding='cp1252')

# %%
df.isna() #checks if there's still rows with empty cells
# Out:
#        Case Number   Date   Year   Type  Country   Area  Location  Activity  \
# 0            False  False  False  False    False  False     False     False
# 1            False  False  False  False    False  False     False     False
# 2            False  False  False  False    False  False     False     False
# 3            False  False  False  False    False  False     False     False
# 4            False  False  False  False    False  False     False     False
# ...            ...    ...    ...    ...      ...    ...       ...       ...
# 25718         True   True   True   True     True   True      True      True
# 25719         True   True   True   True     True   True      True      True
# 25720         True   True   True   True     True   True      True      True
# 25721         True   True   True   True     True   True      True      True
# 25722        False   True   True   True     True   True      True      True
#
#         Name   Sex   ...  Species   Investigator or Source    pdf  \
# 0      False  False  ...     False                   False  False
# 1      False  False  ...      True                   False  False
# 2      False  False  ...      True                   False  False
# 3      False  False  ...     False                   False  False
# 4      False  False  ...     False                   False  False
# ...      ...    ...  ...       ...                     ...    ...
# 25718   True   True  ...      True                    True   True
# 25719   True   True  ...      True                    True   True
# 25720   True   True  ...      True                    True   True
# 25721   True   True  ...      True                    True   True
# 25722   True   True  ...      True                    True   True
#
#        href formula   href  Case Number.1  Case Number.2  original order  \
# 0             False  False          False          False           False
# 1             False  False          False          False           False
# 2             False  False          False          False           False
# 3             False  False          False          False           False
# 4             False  False          False          False           False
# ...             ...    ...            ...            ...             ...
# 25718          True   True           True           True            True
# 25719          True   True           True           True            True
# 25720          True   True           True           True            True
# 25721          True   True           True           True            True
# 25722          True   True           True           True            True
#
#        Unnamed: 22  Unnamed: 23
# 0             True         True
# 1             True         True
# 2             True         True
# 3             True         True
# 4             True         True
# ...            ...          ...
# 25718         True         True
# 25719         True         True
# 25720         True         True
# 25721         True         True
# 25722         True         True
#
# [25723 rows x 24 columns]

# %%
df.dropna(axis=0, how='all') #drop rows of data that are empty
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 8698            0          NaN     NaN         NaN        NaN
# 8699            0          NaN     NaN         NaN        NaN
# 8700            0          NaN     NaN         NaN        NaN
# 8701            0          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 8698               NaN                             NaN          NaN
# 8699               NaN                             NaN          NaN
# 8700               NaN                             NaN          NaN
# 8701               NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
#
#                   Name Sex   ...         Species   \
# 0          Julie Wolfe    F  ...      White shark
# 1      Adyson McNeely     F  ...              NaN
# 2          John Denges    M  ...              NaN
# 3                 male    M  ...        2 m shark
# 4       Gustavo Ramos     M  ...  Tiger shark, 3m
# ...                ...  ...  ...              ...
# 8698               NaN  NaN  ...              NaN
# 8699               NaN  NaN  ...              NaN
# 8700               NaN  NaN  ...              NaN
# 8701               NaN  NaN  ...              NaN
# 25722              NaN  NaN  ...              NaN
#
#                Investigator or Source                       pdf  \
# 0                    R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1      K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2      K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3                      B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4                           A .Kipper      2018.06.04-Ramos.pdf
# ...                               ...                       ...
# 8698                              NaN                       NaN
# 8699                              NaN                       NaN
# 8700                              NaN                       NaN
# 8701                              NaN                       NaN
# 25722                             NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 8698                                                 NaN
# 8699                                                 NaN
# 8700                                                 NaN
# 8701                                                 NaN
# 25722                                                NaN
#
#                                                     href Case Number.1  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                  ...           ...
# 8698                                                 NaN           NaN
# 8699                                                 NaN           NaN
# 8700                                                 NaN           NaN
# 8701                                                 NaN           NaN
# 25722                                                NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0        2018.06.25         6303.0         NaN         NaN
# 1        2018.06.18         6302.0         NaN         NaN
# 2        2018.06.09         6301.0         NaN         NaN
# 3        2018.06.08         6300.0         NaN         NaN
# 4        2018.06.04         6299.0         NaN         NaN
# ...             ...            ...         ...         ...
# 8698            NaN            NaN         NaN         NaN
# 8699            NaN            NaN         NaN         NaN
# 8700            NaN            NaN         NaN         NaN
# 8701            NaN            NaN         NaN         NaN
# 25722           NaN            NaN         NaN         NaN
#
# [8703 rows x 24 columns]

# %%
df.columns=df.columns.str.capitalize().str.replace(' ','-')
df.columns= df.columns.str.rstrip(' ')

# %%
df.sample()
# Out:
#      Case-number      Date    Year      Type        Country Area  \
# 4581  1947.04.00  Apr-1947  1947.0  Provoked  PACIFIC OCEAN  NaN
#
#                                   Location  \
# 4581  Off Central American coast at 8N.79W
#
#                                                Activity              Name  \
# 4581  Moving shark from tuna vessel when boat rolled...  Charles Kaufmann
#
#      Sex-  ... Species-     Investigator-or-source                      Pdf  \
# 4581    M  ...      NaN  C. Kaufmann; S. Springer   1947.04.00-Kaufmann.pdf
#
#                                            Href-formula  \
# 4581  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    Href Case-number.1  \
# 4581  http://sharkattackfile.net/spreadsheets/pdf_di...    1947.04.00
#
#      Case-number.2 Original-order Unnamed:-22 Unnamed:-23
# 4581    1947.04.00         1722.0         NaN         NaN
#
# [1 rows x 24 columns]

# %%
lst = list(df.columns)
print(lst)
# Out:
# ['Case-number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location', 'Activity', 'Name', 'Sex-', 'Age', 'Injury', 'Fatal-(y/n)', 'Time', 'Species-', 'Investigator-or-source', 'Pdf', 'Href-formula', 'Href', 'Case-number.1', 'Case-number.2', 'Original-order', 'Unnamed:-22', 'Unnamed:-23']

# %%
df['Species-'] = df['Species-'].str.rstrip('-')

# %%
#fill NaN values from species column with 'Unknown'
df['Species-'].fillna('Unknown', inplace=True)

# %%
#fill NaN values from activity column with 'Unknown'
df['Activity'].fillna('Unknown', inplace=True)

# %%
# Fix capitalization of fatal(y/n) 
df['Fatal-(y/n)'] = df['Fatal-(y/n)'].str.upper()

# %%
df['Fatal-(y/n)'] = df['Fatal-(y/n)'].str.strip(" ")

# %%
# if column not Y or N, assign as UNKNOWN
df['Fatal-(y/n)'] = np.where((df["Fatal-(y/n)"] == "2017") | (df["Fatal-(y/n)"] == "M"), "UNKNOWN", df["Fatal-(y/n)"])
df["Fatal-(y/n)"].value_counts()
# Out:
# N          4301
# Y          1389
# UNKNOWN      73
# Name: Fatal-(y/n), dtype: int64

# %%
df.rename({'Species-': "Species", "Sex-": "Sex"}, axis=1, inplace=True)

# %%
df.sample()
# Out:
#      Case-number         Date    Year        Type       Country  \
# 4625  1945.03.06  06-Mar-1945  1945.0  Unprovoked  SOUTH AFRICA
#
#                Area    Location Activity            Name Sex  ...  \
# 4625  KwaZulu-Natal  Scottburgh  Walking  David Drummond   M  ...
#
#                                  Species        Investigator-or-source  \
# 4625  Thought to involve a Zambesi shark  D. Drummond, M. Levine, GSAF
#
#                           Pdf  \
# 4625  1945.03.06-Drummond.pdf
#
#                                            Href-formula  \
# 4625  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    Href Case-number.1  \
# 4625  http://sharkattackfile.net/spreadsheets/pdf_di...    1945.03.06
#
#      Case-number.2 Original-order Unnamed:-22 Unnamed:-23
# 4625    1945.03.06         1678.0         NaN         NaN
#
# [1 rows x 24 columns]

# %%
df.Activity.value_counts()
# Out:
# Unknown                                   19968
# Surfing                                     971
# Swimming                                    869
# Fishing                                     431
# Spearfishing                                333
#                                           ...
# Playing with a frisbee in the shallows        1
# Sinking of the ferryboat Dumaguete            1
# Wreck of the Storm King                       1
# Feeding mullet to sharks                      1
# Wreck of  large double sailing canoe          1
# Name: Activity, Length: 1532, dtype: int64

# %%
#df2 = df['activity'].value_counts().apply(lambda x: "Other" if x < 10 else x)
#df2

# %%
#df['activity'].apply(lambda x: "Other" if x < 10 else x)
#d = df.activity.value_counts().to_dict()
#df['activity'] = df['activity'].map(lambda x : x  if d[x] > 10 else 'Other')

# %%
#df.activity.value_counts()

# %%
df.Type.value_counts()
# Out:
# Unprovoked      4595
# Provoked         574
# Invalid          547
# Sea Disaster     239
# Boating          203
# Boat             137
# Questionable       2
# Boatomg            1
# Name: Type, dtype: int64

# %%
#consistent capitalization
df['Activity'] = df['Activity'].str.capitalize()
df['Type'] = df['Type'].str.capitalize()
df['Country'] = df['Country'].str.capitalize()
df['Species'] = df['Species'].str.capitalize()

# %%
#fill NaN values from columns
#df['species'].fillna('Unknown', inplace=True)
#df['country'].fillna('Unknown', inplace=True)
#df['type'].fillna('Unknown', inplace=True)

# %%
df.dropna(subset=["Year"], inplace=True)

# %%
df.sample(10)
# Out:
#        Case-number                  Date    Year          Type       Country  \
# 1871    2002.04.02           02-Apr-2002  2002.0    Unprovoked           Usa
# 3805    1962.07.28           28-Jul-1962  1962.0    Unprovoked           Usa
# 1319    2007.10.06           06-Oct-2007  2007.0    Unprovoked           Usa
# 1255  2008.05.24.b           24-May-2008  2008.0  Sea disaster       Bahamas
# 6021    1852.02.26           26-Feb-1852  1852.0  Sea disaster  South africa
# 1256  2008.05.24.a           24-May-2008  2008.0    Unprovoked        Mexico
# 3708    1964.01.18           18-Jan-1964  1964.0    Unprovoked     Australia
# 4332    1954.07.28           28-Jul-1954  1954.0    Unprovoked     Singapore
# 4761    1940.12.10           10-Dec-1940  1940.0      Provoked     Australia
# 5905  1871.05.22.R  Reported 22-May-1871  1871.0    Unprovoked     Sri lanka
#
#                        Area  \
# 1871                Florida
# 3805         South Carolina
# 1319                Florida
# 1255    Grand Bahama Island
# 6021  Western Cape Province
# 1256                 Guerro
# 3708      Western Australia
# 4332                    NaN
# 4761     Northern Territory
# 5905       Eastern Province
#
#                                                Location  \
# 1871                   New Smyrna Beach, Volusia County
# 3805                  Off Hilton Head, Beaufort County
# 1319  Playalinda Beach, Canaveral National Seashore,...
# 1255                                       Off West End
# 6021                                       Danger Point
# 1256                                        Playa Linda
# 3708                                        Hamelin Bay
# 4332                                   Singapore Harbor
# 4761                                             Darwin
# 5905                                        Trincomalee
#
#                                                Activity  \
# 1871                                             Wading
# 3805                                           Standing
# 1319                                            Surfing
# 1255                                       Sea disaster
# 6021                  Wreck of the steamship birkenhead
# 1256                                            Surfing
# 3708                                         Freediving
# 4332  Closed circuit diving (submerged). diving to r...
# 4761  Collecting fish in military trap when bitten b...
# 5905                                            Bathing
#
#                                  Name Sex  ...  \
# 1871                             male   M  ...
# 3805                     Robert Stein   M  ...
# 1319                             E.H.   M  ...
# 1255                          unknown   M  ...
# 6021                              NaN   M  ...
# 1256                     Bruce Grimes   M  ...
# 3708                     Frank Hastie   M  ...
# 4332  C.B. Larkin, a Royal Navy diver   M  ...
# 4761          Private. Michael Garten   M  ...
# 5905       An officer from H.M. Forte   M  ...
#
#                               Species  \
# 1871                        3'  shark
# 3805  1.8 m to 2.4 m [6' to 8'] shark
# 1319               Blacktip shark, 5'
# 1255             Tiger sharks in area
# 6021                     White sharks
# 1256                        3 m shark
# 3708                        Wobbegong
# 4332                          Unknown
# 4761                          Unknown
# 5905                          Unknown
#
#                                  Investigator-or-source  \
# 1871                                 S. Petersohn, GSAF
# 3805                                           R. Stein
# 1319                                              E. H.
# 1255                                   Associated Press
# 6021             D. Davies, pp.182-184; M. Levine, GSAF
# 1256                                   Associated Press
# 3708  G.P. Whitley, citing Sydney Morning Herald, 1/...
# 4332  New York Times, 7/29/1954; V.M. Coppleson (195...
# 4761        V.M. Coppleson; G.P. Whitley (1951), p. 192
# 5905                               The Argus, 5/22/1871
#
#                                Pdf  \
# 1871           2002.04.02-male.pdf
# 3805          1962.07.28-Stein.pdf
# 1319             2007.10.06-EH.pdf
# 1255  2008.05.24.b-BahamasBoat.pdf
# 6021     1852.02.26-Birkenhead.pdf
# 1256       2008.05.24.a-Grimes.pdf
# 3708         1964.01.18-Hastie.pdf
# 4332   1954.07.28-BritishDiver.pdf
# 4761         1940.12.10-Garten.pdf
# 5905  1871.05.22.R-Trincomalee.pdf
#
#                                            Href-formula  \
# 1871  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3805  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1319  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1255  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6021  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1256  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3708  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4332  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4761  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5905  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    Href Case-number.1  \
# 1871  http://sharkattackfile.net/spreadsheets/pdf_di...    2002.04.02
# 3805  http://sharkattackfile.net/spreadsheets/pdf_di...    1962.07.28
# 1319  http://sharkattackfile.net/spreadsheets/pdf_di...    2007.10.06
# 1255  http://sharkattackfile.net/spreadsheets/pdf_di...  2008.05.24.b
# 6021  http://sharkattackfile.net/spreadsheets/pdf_di...    1852.02.26
# 1256  http://sharkattackfile.net/spreadsheets/pdf_di...  2008.05.24.a
# 3708  http://sharkattackfile.net/spreadsheets/pdf_di...    1964.01.18
# 4332  http://sharkattackfile.net/spreadsheets/pdf_di...    1954.07.28
# 4761  http://sharkattackfile.net/spreadsheets/pdf_di...    1940.12.10
# 5905  http://sharkattackfile.net/spreadsheets/pdf_di...  1871.05.22.R
#
#      Case-number.2 Original-order Unnamed:-22 Unnamed:-23
# 1871    2002.04.02         4432.0         NaN         NaN
# 3805    1962.07.28         2498.0         NaN         NaN
# 1319    2007.10.06         4984.0         NaN         NaN
# 1255  2008.05.24.b         5048.0         NaN         NaN
# 6021    1852.02.26          282.0         NaN         NaN
# 1256  2008.05.24.a         5047.0         NaN         NaN
# 3708    1964.01.18         2595.0         NaN         NaN
# 4332    1954.07.28         1971.0         NaN         NaN
# 4761    1940.12.10         1542.0         NaN         NaN
# 5905  1871.05.22.R          398.0         NaN         NaN
#
# [10 rows x 24 columns]

# %%
df['Year'] = df['Year'].astype(str)

# %%
df['Year'].unique
# Out:
# <bound method Series.unique of 0       2018.0
# 1       2018.0
# 2       2018.0
# 3       2018.0
# 4       2018.0
#          ...
# 6297       0.0
# 6298       0.0
# 6299       0.0
# 6300       0.0
# 6301       0.0
# Name: Year, Length: 6300, dtype: object>

# %%
df['Year'] = df['Year'].map(lambda x: x.rstrip('.0'))

# %%
df["Year"] = df['Year'].apply(lambda x: "" if len(x) != 4 else x)

# %%
df["Year"].unique()
# Out:
# array(['2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011', '',
#        '2009', '2008', '2007', '2006', '2005', '2004', '2003', '2002',
#        '2001', '1999', '1998', '1997', '1996', '1995', '1984', '1994',
#        '1993', '1992', '1991', '1989', '1969', '1988', '1987', '1986',
#        '1985', '1983', '1982', '1981', '1979', '1978', '1977', '1976',
#        '1975', '1974', '1973', '1972', '1971', '1968', '1967', '1966',
#        '1965', '1964', '1963', '1962', '1961', '1959', '1958', '1957',
#        '1956', '1955', '1954', '1953', '1952', '1951', '1949', '1948',
#        '1848', '1947', '1946', '1945', '1944', '1943', '1942', '1941',
#        '1939', '1938', '1937', '1936', '1935', '1934', '1933', '1932',
#        '1931', '1929', '1928', '1927', '1926', '1925', '1924', '1923',
#        '1922', '1921', '1919', '1918', '1917', '1916', '1915', '1914',
#        '1913', '1912', '1911', '1909', '1908', '1907', '1906', '1905',
#        '1904', '1903', '1902', '1901', '1899', '1898', '1897', '1896',
#        '1895', '1894', '1893', '1892', '1891', '1889', '1888', '1887',
#        '1886', '1885', '1884', '1883', '1882', '1881', '1879', '1878',
#        '1877', '1876', '1875', '1874', '1873', '1872', '1871', '1869',
#        '1868', '1867', '1866', '1865', '1864', '1863', '1862', '1861',
#        '1859', '1858', '1857', '1856', '1855', '1853', '1852', '1851',
#        '1849', '1847', '1846', '1845', '1844', '1842', '1841', '1839',
#        '1837', '1836', '1835', '1834', '1832', '1831', '1829', '1828',
#        '1827', '1826', '1825', '1823', '1822', '1819', '1818', '1817',
#        '1816', '1815', '1812', '1811', '1808', '1807', '1805', '1804',
#        '1803', '1802', '1801', '1797', '1792', '1791', '1788', '1787',
#        '1786', '1785', '1784', '1783', '1779', '1776', '1771', '1767',
#        '1764', '1758', '1753', '1751', '1749', '1755', '1748', '1742',
#        '1738', '1733', '1723', '1721', '1703', '1642', '1638', '1637',
#        '1617', '1595', '1555', '1554', '1543'], dtype=object)

# %%
#df["Case-number"] = df['Case-number'].apply(lambda x: "" if x != 0.0 else x)
#df["Case-number"].unique()
# Out:
# array([''], dtype=object)

# %%
df.sample(10)
# Out:
#        Case-number                  Date  Year        Type  \
# 431     2015.04.25           25-Apr-2015  2015  Unprovoked
# 5943    1864.07.25           25-Jul-1864  1864  Unprovoked
# 2737    1988.04.24           24-Apr-1988  1988  Unprovoked
# 4069  1959.08.15.b           15-Aug-1959  1959     Invalid
# 2164  1998.09.16.R  Reported 16-Sep-1998  1998  Unprovoked
# 4288  1955.08.00.c              Aug-1955  1955  Unprovoked
# 1181  2008.12.27.b           27-Dec-2008  2008     Boating
# 1237    2008.07.09           09-Jul-2008  2008  Unprovoked
# 3824  1962.05.00.R              May 1962  1962        Boat
# 5922    1868.05.13           13-May-1868  1868  Unprovoked
#
#                     Country                   Area  \
# 431               Australia        South Australia
# 5943                  Spain       Eastern Catalona
# 2737                    Usa             California
# 4069                    Usa                Florida
# 2164           South africa  Eastern Cape Province
# 4288  North atlantic ocean                Open sea
# 1181              Australia        New South Wales
# 1237                    Usa         North Carolina
# 3824                   Fiji              Viti Levu
# 5922                  India           Hoogly River
#
#                                          Location  \
# 431                                   Fishery Bay
# 5943                                     Badalona
# 2737  North of Morro Rock, San Luis Obispo County
# 4069                      Panama City, Bay County
# 2164                                  Kowie River
# 4288                                          NaN
# 1181                   Long Reef, north of Sydney
# 1237                Emerald Isle, Carteret County
# 3824                                    Near Suva
# 5922                                         Ghat
#
#                               Activity                               Name  \
# 431                            Surfing                      Chris Blowes
# 5943                           Bathing                               male
# 2737                           Surfing                          Mark Rudy
# 4069                            Diving                       Gary Seymour
# 2164  Fishing / washing bait off hands                       Grant Rielly
# 4288                    Treading water                    Wolfgang Emrich
# 1181                          Kayaking                      Steve Kulcsar
# 1237                          Swimming                   Bailleigh Foster
# 3824                           Fishing  17' fishing boat; occupants 2 men
# 5922                          Standing                               male
#
#       Sex  ...                                       Species  \
# 431     M  ...                              White shark, 6 m
# 5943    M  ...                                       Unknown
# 2737    M  ...                                   White shark
# 4069    M  ...                                       Invalid
# 2164    M  ...                                       Unknown
# 4288    M  ...                                       Unknown
# 1181    M  ...                        White shark, 4m to 5m
# 1237    F  ...                                       Unknown
# 3824  NaN  ...                                       Unknown
# 5922    M  ...  Identified as c. gangeticus by dr. j. fayrer
#
#                                  Investigator-or-source  \
# 431                           The Advertiser, 4/25/2015
# 5943                                     C. Moore, GSAF
# 2737          J. McCosker & R.N. Lea; R. Collier, p.102
# 4069  H. D. Baldridge (1994), SAF Case #440 listed i...
# 2164                          Daily Dispatch, 9/16/1998
# 4288               H.D.Baldridge (1994), SAF Case #1489
# 1181                         Canberra Times, 12/28/2008
# 1237                                  C. Creswell, GSAF
# 3824                   Yorkshire Evening News, 5/5/1962
# 5922                                    J. Fayrer, M.D.
#
#                                 Pdf  \
# 431           2015.04.25-Blowes.pdf
# 5943  1864.07.25-Badalona-Spain.pdf
# 2737    1988.04.24-Rudy_Collier.pdf
# 4069       1959.08.15.b-Seymour.pdf
# 2164        1998.09.16.R-Rielly.pdf
# 4288     1955.08.00.c-NV-Emrich.pdf
# 1181       2008.12.27.b-Kulcsar.pdf
# 1237          2008.07.09-Foster.pdf
# 3824       1962.05.00-Suva-Fiji.pdf
# 5922          1868.05.13-Hindoo.pdf
#
#                                            Href-formula  \
# 431   http://sharkattackfile.net/spreadsheets/pdf_di...
# 5943  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2737  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4069  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2164  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4288  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1181  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1237  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3824  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5922  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    Href Case-number.1  \
# 431   http://sharkattackfile.net/spreadsheets/pdf_di...    2015.04.25
# 5943  http://sharkattackfile.net/spreadsheets/pdf_di...    1864.07.25
# 2737  http://sharkattackfile.net/spreadsheets/pdf_di...    1988.04.24
# 4069  http://sharkattackfile.net/spreadsheets/pdf_di...  1959.08.15.b
# 2164  http://sharkattackfile.net/spreadsheets/pdf_di...  1998.09.16.R
# 4288  http://sharkattackfile.net/spreadsheets/pdf_di...  1955.08.00.c
# 1181  http://sharkattackfile.net/spreadsheets/pdf_di...  2008.12.27.b
# 1237  http://sharkattackfile.net/spreadsheets/pdf_di...    2008.07.09
# 3824  http://sharkattackfile.net/spreadsheets/pdf_di...  1962.05.00.R
# 5922  http://sharkattackfile.net/spreadsheets/pdf_di...    1868.05.13
#
#      Case-number.2 Original-order Unnamed:-22 Unnamed:-23
# 431     2015.04.25         5872.0         NaN         NaN
# 5943    1864.07.25          360.0         NaN         NaN
# 2737    1988.04.24         3566.0         NaN         NaN
# 4069  1959.08.15.b         2234.0         NaN         NaN
# 2164  1998.09.16.R         4139.0         NaN         NaN
# 4288  1955.08.00.c         2015.0         NaN         NaN
# 1181  2008.12.27.b         5122.0         NaN         NaN
# 1237    2008.07.09         5066.0         NaN         NaN
# 3824  1962.05.00.R         2479.0         NaN         NaN
# 5922    1868.05.13          381.0         NaN         NaN
#
# [10 rows x 24 columns]
