# %% [markdown]
# ### Libraries

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import DateTime as dtm

# %% [markdown]
# ### Import Data

# %%
df = pd.read_csv("data/attacks.csv", encoding='cp1252')

# %%
#checks if there's still rows with empty cells 
df.isna()
# Out:
#        Case Number   Date   Year   Type  Country   Area  Location  Activity  \
# 0            False  False  False  False    False  False     False     False
# 1            False  False  False  False    False  False     False     False
# 2            False  False  False  False    False  False     False     False
# 3            False  False  False  False    False  False     False     False
# 4            False  False  False  False    False  False     False     False
# ...            ...    ...    ...    ...      ...    ...       ...       ...
# 25718         True   True   True   True     True   True      True      True
# 25719         True   True   True   True     True   True      True      True
# 25720         True   True   True   True     True   True      True      True
# 25721         True   True   True   True     True   True      True      True
# 25722        False   True   True   True     True   True      True      True
#
#         Name   Sex   ...  Species   Investigator or Source    pdf  \
# 0      False  False  ...     False                   False  False
# 1      False  False  ...      True                   False  False
# 2      False  False  ...      True                   False  False
# 3      False  False  ...     False                   False  False
# 4      False  False  ...     False                   False  False
# ...      ...    ...  ...       ...                     ...    ...
# 25718   True   True  ...      True                    True   True
# 25719   True   True  ...      True                    True   True
# 25720   True   True  ...      True                    True   True
# 25721   True   True  ...      True                    True   True
# 25722   True   True  ...      True                    True   True
#
#        href formula   href  Case Number.1  Case Number.2  original order  \
# 0             False  False          False          False           False
# 1             False  False          False          False           False
# 2             False  False          False          False           False
# 3             False  False          False          False           False
# 4             False  False          False          False           False
# ...             ...    ...            ...            ...             ...
# 25718          True   True           True           True            True
# 25719          True   True           True           True            True
# 25720          True   True           True           True            True
# 25721          True   True           True           True            True
# 25722          True   True           True           True            True
#
#        Unnamed: 22  Unnamed: 23
# 0             True         True
# 1             True         True
# 2             True         True
# 3             True         True
# 4             True         True
# ...            ...          ...
# 25718         True         True
# 25719         True         True
# 25720         True         True
# 25721         True         True
# 25722         True         True
#
# [25723 rows x 24 columns]

# %%
#drop rows of data that are empty
df.dropna(axis=0, how='all')
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 8698            0          NaN     NaN         NaN        NaN
# 8699            0          NaN     NaN         NaN        NaN
# 8700            0          NaN     NaN         NaN        NaN
# 8701            0          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# 2               Hawaii                    Habush, Oahu      Surfing
# 3      New South Wales              Arrawarra Headland      Surfing
# 4               Colima                        La Ticla  Free diving
# ...                ...                             ...          ...
# 8698               NaN                             NaN          NaN
# 8699               NaN                             NaN          NaN
# 8700               NaN                             NaN          NaN
# 8701               NaN                             NaN          NaN
# 25722              NaN                             NaN          NaN
#
#                   Name Sex   ...         Species   \
# 0          Julie Wolfe    F  ...      White shark
# 1      Adyson McNeely     F  ...              NaN
# 2          John Denges    M  ...              NaN
# 3                 male    M  ...        2 m shark
# 4       Gustavo Ramos     M  ...  Tiger shark, 3m
# ...                ...  ...  ...              ...
# 8698               NaN  NaN  ...              NaN
# 8699               NaN  NaN  ...              NaN
# 8700               NaN  NaN  ...              NaN
# 8701               NaN  NaN  ...              NaN
# 25722              NaN  NaN  ...              NaN
#
#                Investigator or Source                       pdf  \
# 0                    R. Collier, GSAF      2018.06.25-Wolfe.pdf
# 1      K.McMurray, TrackingSharks.com    2018.06.18-McNeely.pdf
# 2      K.McMurray, TrackingSharks.com     2018.06.09-Denges.pdf
# 3                      B. Myatt, GSAF  2018.06.08-Arrawarra.pdf
# 4                           A .Kipper      2018.06.04-Ramos.pdf
# ...                               ...                       ...
# 8698                              NaN                       NaN
# 8699                              NaN                       NaN
# 8700                              NaN                       NaN
# 8701                              NaN                       NaN
# 25722                             NaN                       NaN
#
#                                             href formula  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                  ...
# 8698                                                 NaN
# 8699                                                 NaN
# 8700                                                 NaN
# 8701                                                 NaN
# 25722                                                NaN
#
#                                                     href Case Number.1  \
# 0      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4      http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
# ...                                                  ...           ...
# 8698                                                 NaN           NaN
# 8699                                                 NaN           NaN
# 8700                                                 NaN           NaN
# 8701                                                 NaN           NaN
# 25722                                                NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0        2018.06.25         6303.0         NaN         NaN
# 1        2018.06.18         6302.0         NaN         NaN
# 2        2018.06.09         6301.0         NaN         NaN
# 3        2018.06.08         6300.0         NaN         NaN
# 4        2018.06.04         6299.0         NaN         NaN
# ...             ...            ...         ...         ...
# 8698            NaN            NaN         NaN         NaN
# 8699            NaN            NaN         NaN         NaN
# 8700            NaN            NaN         NaN         NaN
# 8701            NaN            NaN         NaN         NaN
# 25722           NaN            NaN         NaN         NaN
#
# [8703 rows x 24 columns]

# %%
df.columns=df.columns.str.capitalize().str.replace(' ','-')
df.columns= df.columns.str.rstrip(' ')

# %%
df.sample()
# Out:
#       Case-number Date  Year Type Country Area Location Activity Name Sex-  \
# 24230         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
#
#        ... Species- Investigator-or-source  Pdf Href-formula Href  \
# 24230  ...      NaN                    NaN  NaN          NaN  NaN
#
#       Case-number.1 Case-number.2 Original-order Unnamed:-22 Unnamed:-23
# 24230           NaN           NaN            NaN         NaN         NaN
#
# [1 rows x 24 columns]

# %%
lst = list(df.columns)
print(lst)
# Out:
# ['Case-number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location', 'Activity', 'Name', 'Sex-', 'Age', 'Injury', 'Fatal-(y/n)', 'Time', 'Species-', 'Investigator-or-source', 'Pdf', 'Href-formula', 'Href', 'Case-number.1', 'Case-number.2', 'Original-order', 'Unnamed:-22', 'Unnamed:-23']

# %% [markdown]
# ### Consistent Naming Convention:
#
# #### Column Names
# 1. Capitalized
# 2. Words Separated by '-'

# %%
df['Species-'] = df['Species-'].str.rstrip('-')

# %%
#fill NaN values from species column with 'Unknown'
#df['Species-'].fillna('Unknown', inplace=True)

# %%
#fill NaN values from activity column with 'Unknown'
#df['Activity'].fillna('Unknown', inplace=True)

# %%
# Fix capitalization of fatal(y/n) 
df['Fatal-(y/n)'] = df['Fatal-(y/n)'].str.upper()

# %%
df['Fatal-(y/n)'] = df['Fatal-(y/n)'].str.strip(" ")

# %%
# if column not Y or N, assign as UNKNOWN
df['Fatal-(y/n)'] = np.where((df["Fatal-(y/n)"] == "2017") | (df["Fatal-(y/n)"] == "M"), "UNKNOWN", df["Fatal-(y/n)"])
df["Fatal-(y/n)"].value_counts()
# Out:
# N          4301
# Y          1389
# UNKNOWN      73
# Name: Fatal-(y/n), dtype: int64

# %%
# Remove words ending with dash
df.rename({'Species-': "Species", "Sex-": "Sex", 'Fatal-(y/n)': 'Fatal'}, axis=1, inplace=True)

# %%
#consistent capitalization
df['Activity'] = df['Activity'].str.capitalize()
df['Type'] = df['Type'].str.capitalize()
df['Country'] = df['Country'].str.capitalize()
df['Species'] = df['Species'].str.capitalize()

# %%
#df2 = df['activity'].value_counts().apply(lambda x: "Other" if x < 10 else x)
#df2

# %%
#df['activity'].apply(lambda x: "Other" if x < 10 else x)
#d = df.activity.value_counts().to_dict()
#df['activity'] = df['activity'].map(lambda x : x  if d[x] > 10 else 'Other')

# %%
#df.activity.value_counts()

# %%
df.Type.value_counts()
# Out:
# Unprovoked      4595
# Provoked         574
# Invalid          547
# Sea disaster     239
# Boating          203
# Boat             137
# Questionable       2
# Boatomg            1
# Name: Type, dtype: int64

# %%
#fill NaN values from columns
#df['species'].fillna('Unknown', inplace=True)
#df['country'].fillna('Unknown', inplace=True)
#df['type'].fillna('Unknown', inplace=True)

# %% [markdown]
# ### Fix _Year_ Column
#
# 1. Drop NaN values
# 2. Drop invalid based year format (e.g. year != 52)
# 2. Remove floats (.0)

# %%
df.dropna(subset=["Year"], inplace=True)

# %%
df['Year'] = df['Year'].astype(str)

# %%
df['Year'].unique
# Out:
# <bound method Series.unique of 0       2018.0
# 1       2018.0
# 2       2018.0
# 3       2018.0
# 4       2018.0
#          ...
# 6297       0.0
# 6298       0.0
# 6299       0.0
# 6300       0.0
# 6301       0.0
# Name: Year, Length: 6300, dtype: object>

# %%
df['Year'] = df['Year'].map(lambda x: x.rstrip('.0'))

# %%
df["Year"].unique()
# Out:
# array(['2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011',
#        '201', '2009', '2008', '2007', '2006', '2005', '2004', '2003',
#        '2002', '2001', '2', '1999', '1998', '1997', '1996', '1995',
#        '1984', '1994', '1993', '1992', '1991', '199', '1989', '1969',
#        '1988', '1987', '1986', '1985', '1983', '1982', '1981', '198',
#        '1979', '1978', '1977', '1976', '1975', '1974', '1973', '1972',
#        '1971', '197', '1968', '1967', '1966', '1965', '1964', '1963',
#        '1962', '1961', '196', '1959', '1958', '1957', '1956', '1955',
#        '1954', '1953', '1952', '1951', '195', '1949', '1948', '1848',
#        '1947', '1946', '1945', '1944', '1943', '1942', '1941', '194',
#        '1939', '1938', '1937', '1936', '1935', '1934', '1933', '1932',
#        '1931', '193', '1929', '1928', '1927', '1926', '1925', '1924',
#        '1923', '1922', '1921', '192', '1919', '1918', '1917', '1916',
#        '1915', '1914', '1913', '1912', '1911', '191', '1909', '1908',
#        '1907', '1906', '1905', '1904', '1903', '1902', '1901', '19',
#        '1899', '1898', '1897', '1896', '1895', '1894', '1893', '1892',
#        '1891', '189', '1889', '1888', '1887', '1886', '1885', '1884',
#        '1883', '1882', '1881', '188', '1879', '1878', '1877', '1876',
#        '1875', '1874', '1873', '1872', '1871', '187', '1869', '1868',
#        '1867', '1866', '1865', '1864', '1863', '1862', '1861', '186',
#        '1859', '1858', '1857', '1856', '1855', '1853', '1852', '1851',
#        '185', '1849', '1847', '1846', '1845', '1844', '1842', '1841',
#        '184', '1839', '1837', '1836', '1835', '1834', '1832', '1831',
#        '183', '1829', '1828', '1827', '1826', '1825', '1823', '1822',
#        '1819', '1818', '1817', '1816', '1815', '1812', '1811', '181',
#        '1808', '1807', '1805', '1804', '1803', '1802', '1801', '18',
#        '1797', '1792', '1791', '1788', '1787', '1786', '1785', '1784',
#        '1783', '178', '1779', '1776', '1771', '1767', '1764', '1758',
#        '1753', '1751', '1749', '1755', '1748', '1742', '1738', '1733',
#        '1723', '1721', '1703', '17', '1642', '1638', '1637', '1617',
#        '1595', '158', '1555', '1554', '1543', '5', '77', ''], dtype=object)

# %%
df["Year"] = df['Year'].apply(lambda x: "" if len(x) != 4 else x)

# %%
df["Year"].unique()
# Out:
# array(['2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011', '',
#        '2009', '2008', '2007', '2006', '2005', '2004', '2003', '2002',
#        '2001', '1999', '1998', '1997', '1996', '1995', '1984', '1994',
#        '1993', '1992', '1991', '1989', '1969', '1988', '1987', '1986',
#        '1985', '1983', '1982', '1981', '1979', '1978', '1977', '1976',
#        '1975', '1974', '1973', '1972', '1971', '1968', '1967', '1966',
#        '1965', '1964', '1963', '1962', '1961', '1959', '1958', '1957',
#        '1956', '1955', '1954', '1953', '1952', '1951', '1949', '1948',
#        '1848', '1947', '1946', '1945', '1944', '1943', '1942', '1941',
#        '1939', '1938', '1937', '1936', '1935', '1934', '1933', '1932',
#        '1931', '1929', '1928', '1927', '1926', '1925', '1924', '1923',
#        '1922', '1921', '1919', '1918', '1917', '1916', '1915', '1914',
#        '1913', '1912', '1911', '1909', '1908', '1907', '1906', '1905',
#        '1904', '1903', '1902', '1901', '1899', '1898', '1897', '1896',
#        '1895', '1894', '1893', '1892', '1891', '1889', '1888', '1887',
#        '1886', '1885', '1884', '1883', '1882', '1881', '1879', '1878',
#        '1877', '1876', '1875', '1874', '1873', '1872', '1871', '1869',
#        '1868', '1867', '1866', '1865', '1864', '1863', '1862', '1861',
#        '1859', '1858', '1857', '1856', '1855', '1853', '1852', '1851',
#        '1849', '1847', '1846', '1845', '1844', '1842', '1841', '1839',
#        '1837', '1836', '1835', '1834', '1832', '1831', '1829', '1828',
#        '1827', '1826', '1825', '1823', '1822', '1819', '1818', '1817',
#        '1816', '1815', '1812', '1811', '1808', '1807', '1805', '1804',
#        '1803', '1802', '1801', '1797', '1792', '1791', '1788', '1787',
#        '1786', '1785', '1784', '1783', '1779', '1776', '1771', '1767',
#        '1764', '1758', '1753', '1751', '1749', '1755', '1748', '1742',
#        '1738', '1733', '1723', '1721', '1703', '1642', '1638', '1637',
#        '1617', '1595', '1555', '1554', '1543'], dtype=object)

# %%
df["Year"] = df['Year'].apply(lambda x: "" if len(x) != 4 else x)

# %%
df['Year'] = pd.to_numeric(df['Year'], errors='coerce')
df.dropna(subset=['Year'], inplace=True)
df['Year'] = pd.to_datetime(df['Year'], format='%Y', exact=True, errors='ignore')

# %%
df['Ýear'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\miniconda3\envs\ironhack\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\miniconda3\envs\ironhack\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\miniconda3\envs\ironhack\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Ýear'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[621], line 1
# ----> 1 df['Ýear'].unique()
#
# File ~\miniconda3\envs\ironhack\lib\site-packages\pandas\core\frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File ~\miniconda3\envs\ironhack\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'Ýear'

# %%
df.sample()
# Out:
#      Case-number        Date  Year        Type Country      Area  \
# 3365  1971.04.06  6-Apr-1971  1971  Unprovoked  Mexico  Guerrero
#
#                         Location Activity        Name Sex  ... Species  \
# 3365  Copacabana Beach, Acapulco  Surfing  Jimmy Rowe   M  ...     NaN
#
#      Investigator-or-source                  Pdf  \
# 3365     A.Resciniti, p.109  1971.04.06-Rowe.pdf
#
#                                            Href-formula  \
# 3365  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    Href Case-number.1  \
# 3365  http://sharkattackfile.net/spreadsheets/pdf_di...    1971.04.06
#
#      Case-number.2 Original-order Unnamed:-22 Unnamed:-23
# 3365    1971.04.06         2938.0         NaN         NaN
#
# [1 rows x 24 columns]

# %%
df["Year"].dtypes
# Out:
# dtype('O')

# %%
#df["Case-number"] = df['Case-number'].apply(lambda x: "" if x != 0.0 else x)
#df["Case-number"].unique()

# %%
df['Year'].unique()
# Out:
# array([datetime.date(2018, 1, 1), datetime.date(2017, 1, 1),
#        datetime.date(2016, 1, 1), datetime.date(2015, 1, 1),
#        datetime.date(2014, 1, 1), datetime.date(2013, 1, 1),
#        datetime.date(2012, 1, 1), datetime.date(2011, 1, 1),
#        datetime.date(2009, 1, 1), datetime.date(2008, 1, 1),
#        datetime.date(2007, 1, 1), datetime.date(2006, 1, 1),
#        datetime.date(2005, 1, 1), datetime.date(2004, 1, 1),
#        datetime.date(2003, 1, 1), datetime.date(2002, 1, 1),
#        datetime.date(2001, 1, 1), datetime.date(1999, 1, 1),
#        datetime.date(1998, 1, 1), datetime.date(1997, 1, 1),
#        datetime.date(1996, 1, 1), datetime.date(1995, 1, 1),
#        datetime.date(1984, 1, 1), datetime.date(1994, 1, 1),
#        datetime.date(1993, 1, 1), datetime.date(1992, 1, 1),
#        datetime.date(1991, 1, 1), datetime.date(1989, 1, 1),
#        datetime.date(1969, 1, 1), datetime.date(1988, 1, 1),
#        datetime.date(1987, 1, 1), datetime.date(1986, 1, 1),
#        datetime.date(1985, 1, 1), datetime.date(1983, 1, 1),
#        datetime.date(1982, 1, 1), datetime.date(1981, 1, 1),
#        datetime.date(1979, 1, 1), datetime.date(1978, 1, 1),
#        datetime.date(1977, 1, 1), datetime.date(1976, 1, 1),
#        datetime.date(1975, 1, 1), datetime.date(1974, 1, 1),
#        datetime.date(1973, 1, 1), datetime.date(1972, 1, 1),
#        datetime.date(1971, 1, 1), datetime.date(1968, 1, 1),
#        datetime.date(1967, 1, 1), datetime.date(1966, 1, 1),
#        datetime.date(1965, 1, 1), datetime.date(1964, 1, 1),
#        datetime.date(1963, 1, 1), datetime.date(1962, 1, 1),
#        datetime.date(1961, 1, 1), datetime.date(1959, 1, 1),
#        datetime.date(1958, 1, 1), datetime.date(1957, 1, 1),
#        datetime.date(1956, 1, 1), datetime.date(1955, 1, 1),
#        datetime.date(1954, 1, 1), datetime.date(1953, 1, 1),
#        datetime.date(1952, 1, 1), datetime.date(1951, 1, 1),
#        datetime.date(1949, 1, 1), datetime.date(1948, 1, 1),
#        datetime.date(1848, 1, 1), datetime.date(1947, 1, 1),
#        datetime.date(1946, 1, 1), datetime.date(1945, 1, 1),
#        datetime.date(1944, 1, 1), datetime.date(1943, 1, 1),
#        datetime.date(1942, 1, 1), datetime.date(1941, 1, 1),
#        datetime.date(1939, 1, 1), datetime.date(1938, 1, 1),
#        datetime.date(1937, 1, 1), datetime.date(1936, 1, 1),
#        datetime.date(1935, 1, 1), datetime.date(1934, 1, 1),
#        datetime.date(1933, 1, 1), datetime.date(1932, 1, 1),
#        datetime.date(1931, 1, 1), datetime.date(1929, 1, 1),
#        datetime.date(1928, 1, 1), datetime.date(1927, 1, 1),
#        datetime.date(1926, 1, 1), datetime.date(1925, 1, 1),
#        datetime.date(1924, 1, 1), datetime.date(1923, 1, 1),
#        datetime.date(1922, 1, 1), datetime.date(1921, 1, 1),
#        datetime.date(1919, 1, 1), datetime.date(1918, 1, 1),
#        datetime.date(1917, 1, 1), datetime.date(1916, 1, 1),
#        datetime.date(1915, 1, 1), datetime.date(1914, 1, 1),
#        datetime.date(1913, 1, 1), datetime.date(1912, 1, 1),
#        datetime.date(1911, 1, 1), datetime.date(1909, 1, 1),
#        datetime.date(1908, 1, 1), datetime.date(1907, 1, 1),
#        datetime.date(1906, 1, 1), datetime.date(1905, 1, 1),
#        datetime.date(1904, 1, 1), datetime.date(1903, 1, 1),
#        datetime.date(1902, 1, 1), datetime.date(1901, 1, 1),
#        datetime.date(1899, 1, 1), datetime.date(1898, 1, 1),
#        datetime.date(1897, 1, 1), datetime.date(1896, 1, 1),
#        datetime.date(1895, 1, 1), datetime.date(1894, 1, 1),
#        datetime.date(1893, 1, 1), datetime.date(1892, 1, 1),
#        datetime.date(1891, 1, 1), datetime.date(1889, 1, 1),
#        datetime.date(1888, 1, 1), datetime.date(1887, 1, 1),
#        datetime.date(1886, 1, 1), datetime.date(1885, 1, 1),
#        datetime.date(1884, 1, 1), datetime.date(1883, 1, 1),
#        datetime.date(1882, 1, 1), datetime.date(1881, 1, 1),
#        datetime.date(1879, 1, 1), datetime.date(1878, 1, 1),
#        datetime.date(1877, 1, 1), datetime.date(1876, 1, 1),
#        datetime.date(1875, 1, 1), datetime.date(1874, 1, 1),
#        datetime.date(1873, 1, 1), datetime.date(1872, 1, 1),
#        datetime.date(1871, 1, 1), datetime.date(1869, 1, 1),
#        datetime.date(1868, 1, 1), datetime.date(1867, 1, 1),
#        datetime.date(1866, 1, 1), datetime.date(1865, 1, 1),
#        datetime.date(1864, 1, 1), datetime.date(1863, 1, 1),
#        datetime.date(1862, 1, 1), datetime.date(1861, 1, 1),
#        datetime.date(1859, 1, 1), datetime.date(1858, 1, 1),
#        datetime.date(1857, 1, 1), datetime.date(1856, 1, 1),
#        datetime.date(1855, 1, 1), datetime.date(1853, 1, 1),
#        datetime.date(1852, 1, 1), datetime.date(1851, 1, 1),
#        datetime.date(1849, 1, 1), datetime.date(1847, 1, 1),
#        datetime.date(1846, 1, 1), datetime.date(1845, 1, 1),
#        datetime.date(1844, 1, 1), datetime.date(1842, 1, 1),
#        datetime.date(1841, 1, 1), datetime.date(1839, 1, 1),
#        datetime.date(1837, 1, 1), datetime.date(1836, 1, 1),
#        datetime.date(1835, 1, 1), datetime.date(1834, 1, 1),
#        datetime.date(1832, 1, 1), datetime.date(1831, 1, 1),
#        datetime.date(1829, 1, 1), datetime.date(1828, 1, 1),
#        datetime.date(1827, 1, 1), datetime.date(1826, 1, 1),
#        datetime.date(1825, 1, 1), datetime.date(1823, 1, 1),
#        datetime.date(1822, 1, 1), datetime.date(1819, 1, 1),
#        datetime.date(1818, 1, 1), datetime.date(1817, 1, 1),
#        datetime.date(1816, 1, 1), datetime.date(1815, 1, 1),
#        datetime.date(1812, 1, 1), datetime.date(1811, 1, 1),
#        datetime.date(1808, 1, 1), datetime.date(1807, 1, 1),
#        datetime.date(1805, 1, 1), datetime.date(1804, 1, 1),
#        datetime.date(1803, 1, 1), datetime.date(1802, 1, 1),
#        datetime.date(1801, 1, 1), datetime.date(1797, 1, 1),
#        datetime.date(1792, 1, 1), datetime.date(1791, 1, 1),
#        datetime.date(1788, 1, 1), datetime.date(1787, 1, 1),
#        datetime.date(1786, 1, 1), datetime.date(1785, 1, 1),
#        datetime.date(1784, 1, 1), datetime.date(1783, 1, 1),
#        datetime.date(1779, 1, 1), datetime.date(1776, 1, 1),
#        datetime.date(1771, 1, 1), datetime.date(1767, 1, 1),
#        datetime.date(1764, 1, 1), datetime.date(1758, 1, 1),
#        datetime.date(1753, 1, 1), datetime.date(1751, 1, 1),
#        datetime.date(1749, 1, 1), datetime.date(1755, 1, 1),
#        datetime.date(1748, 1, 1), datetime.date(1742, 1, 1),
#        datetime.date(1738, 1, 1), datetime.date(1733, 1, 1),
#        datetime.date(1723, 1, 1), datetime.date(1721, 1, 1),
#        datetime.date(1703, 1, 1), NaT], dtype=object)

# %%
df[['Year','Country', 'Type','Fatal']].head(100)
# Out:
#          Year      Country        Type Fatal
# 0  2018-01-01          Usa     Boating     N
# 1  2018-01-01          Usa  Unprovoked     N
# 2  2018-01-01          Usa     Invalid     N
# 3  2018-01-01    Australia  Unprovoked     N
# 4  2018-01-01       Mexico    Provoked     N
# ..        ...          ...         ...   ...
# 95 2017-01-01          Usa  Unprovoked     N
# 96 2017-01-01    Australia  Unprovoked     N
# 97 2017-01-01          Usa  Unprovoked     N
# 98 2017-01-01        Spain     Invalid   NaN
# 99 2017-01-01  New zealand  Unprovoked     N
#
# [100 rows x 4 columns]

# %%
df.to_csv('data/clean_sharks_export.csv')
